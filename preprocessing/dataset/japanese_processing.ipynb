# %%
valid = "ぁあぃいぅうぇえぉおかがきぎくぐけげこごさざしじすずせぜそぞただちぢっつづてでとどなにぬねのはばぱひびぴふぶぷへべぺほぼぽまみむめもゃやゅゆょよらりるれろゎわゐゑをんゔゕゖ"

# %%
import pandas as pd
df = pd.read_csv("chinese_jp_kor_excel_data.csv")
columns = ['Column9', 'Column10', 'Column11']

# %%
li1 = df['Column9'].tolist()
li2 = df['Column10'].tolist()
li3 = df['Column11'].tolist()
lis = [li1, li2, li3]

# %%
def jpstrip(s):
    res = ""
    if type(s) == float:
        return ""
    for i in range(len(s)):
        if valid.find(s[i]) == -1:
            print(s[i:])
            return s[0:i]
    return s

# %%
for li in lis:
    for i in range(len(li)):
        li[i] = jpstrip(li[i])

# %%
df['Column9'] = li1
df['Column10'] = li2
df['Column11'] = li3

# %%
df.head()
# Out:
#   Column1  Column2 Column3 Column4 Column5 Column6 Column7 Column8 Column9  \
# 0       犬    598.0    quǎn   hyun2   khién     NaN     ián   2qyoe      けん
# 1       馬    599.0      mǎ    maa5      mâ     ma1     NaN     3mo       め
# 2       西    603.0      xī    sai1      sî     xi1     sai     1xi      さい
# 3       車    604.0     chē     ce1    chhâ     ca1   chhia   1tsho      しゃ
# 4       酉    650.0     yǒu    jau5      yu     NaN      iú     NaN       ゆ
#
#   Column10  ... Column19 Column20 Column21 Column22 Column23 Column24  \
# 0       けん  ...      NaN      NaN      NaN      NaN      NaN      NaN
# 1        め  ...      NaN      NaN      NaN      NaN      NaN      NaN
# 2       さい  ...      NaN      NaN      NaN      NaN      NaN      NaN
# 3       しゃ  ...      NaN      NaN      NaN      NaN      NaN      NaN
# 4        ゆ  ...      NaN      NaN      NaN      NaN      NaN      NaN
#
#   Column25 Column26 Column27 Column28
# 0      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN
#
# [5 rows x 28 columns]

# %%
df.to_csv("chinese_jp_kor_excel_data_jp_corrected.csv", encoding='utf-8')
